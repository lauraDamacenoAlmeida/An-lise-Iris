# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
plt.rc('figure', figsize = (15,8))

# %%
df = pd.read_csv('data/iris.data.csv')
df.head()
# Out:
#    sepal length  sepal width  petal length  petal width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
area = plt.figure()

# %%
g1 = area.add_subplot(2,2,1)
g2 = area.add_subplot(2,2,2)
g3 = area.add_subplot(2,2,3)
g4 = area.add_subplot(2,2,4)

# %%
g1.scatter(df['petal length'],df['sepal length'] )
g1.set_title('Petal X Sepal Length')
# Out:
# Text(0.5, 1.0, 'Petal X Sepal Length')

# %%
g2.hist(df['sepal length'])
g2.set_title('sepal length')
# Out:
# Text(0.5, 1.0, 'sepal length')

# %%
#pegar amostra aleatória e gerar um gráfico
#.sample(numero de registros) ==> ele pega aleatoriamente valores no dataframe
# range() ==> para ordenar os index selecionados
dados = df['petal width'].sample(100)
dados.index = range(len(dados))
g3.plot(dados,'go')
g3.set_title('Petal length')
# Out:
# Text(0.5, 1.0, 'Petal length')

# %%
#grupo_flores.mean().index ==> retorna os tipos das plantas
grupo_flores = df.groupby('class')['sepal length']
label = grupo_flores.mean().index
valores = grupo_flores.mean().values
g4.bar(label,valores)
g4.set_title('Tamanho de sépala médio por tipo de flor')
# Out:
# Text(0.5, 1.0, 'Tamanho de sépala médio por tipo de flor')

# %%
area

# %%
#bbox_inches ==> tira a borda branca das imagens
area.savefig('grafico.png',dpi = 300,bbox_inches = 'tight')

# %%
plt.rc('figure', figsize = (15,10))
area2 = plt.figure()

# %%
g1 = area2.add_subplot(2,2,1)
g2 = area2.add_subplot(2,2,2)
g3 = area2.add_subplot(2,2,3)
g4 = area2.add_subplot(2,2,4)

# %%
area3 = plt.figure()
plt.rc('figure', figsize = (15,10))

# %%
g5 = area3.add_subplot(2,2,1)
g6 = area3.add_subplot(2,2,2)

# %%
g1.bar(df['class'],df['petal length'])
g1.set_ylabel('Petal Lenght')
g1.set_xlabel('class')
g1.set_title('Petal Lenght X Class')
# Out:
# Text(0.5, 1.0, 'Petal Lenght X Class')

# %%
g2.bar(df['class'],df['sepal length'])
g2.set_ylabel('Sepal Lenght')
g2.set_xlabel('class')
g2.set_title('Sepal Lenght X Class')
# Out:
# Text(0.5, 1.0, 'Sepal Lenght X Class')

# %%
g3.scatter(df['petal length'],df['sepal length'])
g3.set_xlabel('Petal Length')
g3.set_ylabel('Sepal Length')
g3.set_title('Sepal Length X Petal Length')
# Out:
# Text(0.5, 1.0, 'Sepal Length X Petal Length')

# %%
var_sepala = df.groupby(['class'])['sepal length']
label = var_sepala.mean().index
valor = var_sepala.mean().values
g4.bar(label,valor)
g4.set_title('Media do tamanho de sépalas por classe')
# Out:
# Text(0.5, 1.0, 'Media do tamanho de sépalas por classe')

# %%
group_width = df.groupby('class')['sepal width']
label = group_width.mean().index
valor = group_width.mean().values
g5.bar(label,valor)
g5.set_title('Média de largura da sépala por classe')
# Out:
# Text(0.5, 1.0, 'Média de largura da sépala por classe')

# %%
group_petal = df.groupby('class')['petal width']
values = group_petal.mean()
label = values.index
g6.bar(label,values)
g6.set_title('Média de largura da pétala por classe')
# Out:
# Text(0.5, 1.0, 'Média de largura da pétala por classe')

# %%
area2

# %%
area2.savefig('grafico1.png',dpi = 300,bbox_inches = 'tight')

# %%
area3

# %%
area3.savefig('grafico2.png',dpi = 300,bbox_inches = 'tight')

# %%
plt.rc('figure', figsize = (15,10))
area4 = plt.figure()

# %%
g1 = area4.add_subplot(2,2,1)
g2 = area4.add_subplot(2,2,2)
g3 = area4.add_subplot(2,2,3)

# %%
selecao = df['class'] == 'Iris-setosa'
g1.scatter(df[selecao]['petal length'],df[selecao]['sepal length'])
g1.set_xlabel('petal length')
g1.set_ylabel('sepal length')
g1.set_title('Iris setosa')
# Out:
# Text(0.5, 1.0, 'Iris setosa')

# %%
selecao = df['class'] == 'Iris-versicolor'
g2.scatter(df[selecao]['petal length'],df[selecao]['sepal length'])
g2.set_xlabel('petal length')
g2.set_ylabel('sepal length')
g2.set_title('Iris versicolor')
# Out:
# Text(0.5, 1.0, 'Iris versicolor')

# %%
selecao = df['class'] == 'Iris-virginica'
g3.scatter(df[selecao]['petal length'],df[selecao]['sepal length'])
g3.set_xlabel('petal length')
g3.set_ylabel('sepal length')
g3.set_title('Iris virginica')
# Out:
# Text(0.5, 1.0, 'Iris virginica')

# %%
area4

# %%
area4.savefig('grafico3.png',dpi = 300,bbox_inches = 'tight')

# %%
media_class = df.groupby('class').mean()

# %%
media_class.values
# Out:
# array([[5.006, 3.418, 1.464, 0.244],
#        [5.936, 2.77 , 4.26 , 1.326],
#        [6.588, 2.974, 5.552, 2.026]])

# %%
media_class.index
# Out:
# Index(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype='object', name='class')

# %%
media_class
# Out:
#                  sepal length  sepal width  petal length  petal width
# class
# Iris-setosa             5.006        3.418         1.464        0.244
# Iris-versicolor         5.936        2.770         4.260        1.326
# Iris-virginica          6.588        2.974         5.552        2.026

# %%
colors_list = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue', 'lightgreen', 'pink']
explode_list = [0.1, 0, 0.1] # ratio for each continent with which to offset each wedge.

media_class['sepal length'].plot(kind='pie',
                                figsize=(5, 6),
                                autopct='%1.1f%%',
                                colors=colors_list,
                                shadow=True,
                                labels=None,
                                pctdistance=1.12,
                                explode=explode_list)

plt.title('Média do tamanho da sépala por classe',y=1.05)
plt.axis('equal') 
plt.legend(labels=media_class.index, loc='upper left')

# %%
maior = df[df['petal length']>3.2]

# %%
df[df['petal length']>4.5].groupby('class')['petal length'].count().plot.bar(figsize=(10, 6))
plt.title('Total de pétalas maiores que 4.5cm',y=1.15)
# Out:
# Text(0.5, 1.15, 'Total de pétalas maiores que 4.5cm')

# %%
petal_class = df[df['petal length']>5].groupby('class').count()
petal_class['petal length'].plot.pie(figsize=(5, 6),
                                autopct='%1.1f%%',explode=[0.1,0],shadow=True, labels=None)
plt.title('Total de pétalas maiores que 5cm',y=1.10)
plt.legend(labels=petal_class.index, loc='upper left')

# %%
fig = plt.figure() # create figure
ax0 = fig.add_subplot(1, 2, 1) # add subplot 1 (1 row, 2 columns, first plot)
ax1 = fig.add_subplot(1, 2, 2) # add subplot 2 (1 row, 2 columns, second plot). See tip below**

#Primeiro gráfico
colors_list = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue', 'lightgreen', 'pink']
explode_list = [0.1, 0, 0.1] # ratio for each continent with which to offset each wedge.

media_class['sepal length'].plot(kind='pie',
                                figsize=(20, 6),
                                autopct='%1.1f%%',
                                colors=colors_list,
                                shadow=True,
                                explode=explode_list,ax=ax0)

ax0.set_title('Média do tamanho da sépala por classe',y=1.05)
#ax0.set_legend(labels=media_class.index, loc='upper left') 


#Segundo gráfico 
petal_class = df[df['petal length']>5].groupby('class').count()
petal_class['petal length'].plot.pie(figsize=(20, 6),
                                autopct='%1.1f%%',explode=[0.1,0],shadow=True,ax=ax1)
ax1.set_title('Total de pétalas maiores que 5cm',y=1.10)
#ax1.set_legend(labels=petal_class.index, loc='upper left') 
fig.savefig('grafico5.png',dpi = 300,bbox_inches = 'tight')

# %%
plt.rc('figure', figsize = (15,10))
fig2 = plt.figure() # create figure
ax0 = fig2.add_subplot(2,2,1)
ax1 = fig2.add_subplot(2,2,2)
ax2 = fig2.add_subplot(2,2,3)

ax0.scatter(df['petal length'],df['sepal width'])
ax0.set_xlabel('Petal Length')
ax0.set_ylabel('Sepal width')
ax0.set_title('Tendencia do tamanho da pétala X largura da Sépala')

ax1.scatter(df['petal width'],df['sepal width'])
ax1.set_xlabel('Petal width')
ax1.set_ylabel('Sepal width')
ax1.set_title('Tendencia do largura da pétala X largura da Sépala')

ax2.scatter(df['petal width'],df['petal length'])
ax2.set_xlabel('Petal width')
ax2.set_ylabel('Petal length')
ax2.set_title('Tendencia do largura da pétala X tamanho da pétala')

fig2.savefig('TendenciasPetalasXSepala.png',dpi = 300,bbox_inches = 'tight')
